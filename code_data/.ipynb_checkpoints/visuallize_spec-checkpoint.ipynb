# %%
import os
import glob
import numpy as np
import json
import matplotlib.pyplot as plt
import random
import h5py
import librosa
import sys
import util
print sys.platform
# Out:
# darwin
# /Users/bochen/anaconda2/envs/env1/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
if sys.platform in ["linux", "linux2"]: # on server
    path_data = "../../../data"
if sys.platform == "darwin":    # on local mac
    path_data = "/Users/bochen/Desktop/data"

path_set = os.path.join(path_data, "set_001")
path_feat = os.path.join(path_set, "feat")

data_types = ["train", "valid", "test"]
data_type = "train"

print "##### %s #####" % data_type
path_feat_cur = os.path.join(path_feat, data_type)

filenames = glob.glob(path_feat_cur + "/*.h5")
filenames.sort()
filename = filenames[20]
print filename

f = h5py.File(filename)
mag = np.array(f["mag"])
mask = np.array(f["mask"])
f.close()
# Out:
# ##### train #####
# /Users/bochen/Desktop/data/set_001/feat/train/000020@vn0082-vn0486.h5

# %%
fig, ax = plt.subplots(2, 2,figsize=(20,5))
ax[0,0].imshow(mag)
ax[0,1].imshow(mask[0,...]+mask[1,...])
ax[1,0].imshow(mask[0,...])
ax[1,1].imshow(mask[1,...])

# %%
mask
# Out:
# array([[[False, False,  True, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[ True,  True, False, ..., False,  True, False],
#         [ True,  True,  True, ...,  True,  True, False],
#         [ True,  True, False, ...,  True, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]]])
